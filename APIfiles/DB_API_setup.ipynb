# %%
pip install psycopg2-binary sqlalchemy

# %%
# Uploading appointments data files to PostgreSQL database

import pandas as pd
from sqlalchemy import create_engine

# Step 1: Load CSV
appointments_df = pd.read_csv(r"C:\Users\aamreen_quantum-i\OneDrive\Desktop\Symptoms_checker\symptoms_checker\CSV Data\doctor_appointment_load.csv")

# Step 2: Connection string (modify with your DB credentials)
USER = "postgres"       # e.g., postgres
PASSWORD = "12345678"   # e.g., 1234
HOST = "localhost"           # or your DB server IP
PORT = "5432"                # default postgres port
DBNAME = "agentdata"       # e.g., hospital_db

# Step 3: Create engine
engine = create_engine(f"postgresql+psycopg2://{USER}:{PASSWORD}@{HOST}:{PORT}/{DBNAME}")

# Step 4: Save DataFrame to Postgres (inside schema BHC)
appointments_df.to_sql(
    "appointments_df",  # table name in postgres
    engine,
    schema="BHC",           # schema name you created
    if_exists="replace",    # options: 'fail', 'replace', 'append'
    index=False             # don’t save pandas index
)

print("Data saved successfully to Postgres!")

# %%
# Uploading leave data files to PostgreSQL database

# Step 1: Load CSV
leaves_df = pd.read_csv(r"C:\Users\aamreen_quantum-i\OneDrive\Desktop\Symptoms_checker\symptoms_checker\CSV Data\Leavedata.csv")

# Step 2: Connection string (modify with your DB credentials)
USER = "postgres"       # e.g., postgres
PASSWORD = "12345678"   # e.g., 1234
HOST = "localhost"           # or your DB server IP
PORT = "5432"                # default postgres port
DBNAME = "agentdata"       # e.g., hospital_db

# Step 3: Create engine
engine = create_engine(f"postgresql+psycopg2://{USER}:{PASSWORD}@{HOST}:{PORT}/{DBNAME}")

# Step 4: Save DataFrame to Postgres (inside schema BHC)
leaves_df.to_sql(
    "leaves_df",  # table name in postgres
    engine,
    schema="BHC",           # schema name you created
    if_exists="replace",    # options: 'fail', 'replace', 'append'
    index=False             # don’t save pandas index
)


print("Data saved successfully to Postgres!")

# %%
# Uploading doctors data files to PostgreSQL database

# Step 1: Load CSV
doctors_df = pd.read_csv(r"C:\Users\aamreen_quantum-i\OneDrive\Desktop\Symptoms_checker\symptoms_checker\CSV Data\doctors.csv")

# Step 2: Connection string (modify with your DB credentials)
USER = "postgres"       # e.g., postgres
PASSWORD = "12345678"   # e.g., 1234
HOST = "localhost"           # or your DB server IP
PORT = "5432"                # default postgres port
DBNAME = "agentdata"       # e.g., hospital_db

# Step 3: Create engine
engine = create_engine(f"postgresql+psycopg2://{USER}:{PASSWORD}@{HOST}:{PORT}/{DBNAME}")

# Step 4: Save DataFrame to Postgres (inside schema BHC)
doctors_df.to_sql(
    "doctors_df",  # table name in postgres
    engine,
    schema="BHC",           # schema name you created
    if_exists="replace",    # options: 'fail', 'replace', 'append'
    index=False             # don’t save pandas index
)


print("Data saved successfully to Postgres!")

# %%
# Uploading age_segment data files to PostgreSQL database

# Step 1: Load CSV
age_segment = pd.read_csv(r"C:\Users\aamreen_quantum-i\OneDrive\Desktop\Symptoms_checker\symptoms_checker\CSV Data\Segments\age_group_segment.csv")

# Step 2: Connection string (modify with your DB credentials)
USER = "postgres"       # e.g., postgres
PASSWORD = "12345678"   # e.g., 1234
HOST = "localhost"           # or your DB server IP
PORT = "5432"                # default postgres port
DBNAME = "agentdata"       # e.g., hospital_db

# Step 3: Create engine
engine = create_engine(f"postgresql+psycopg2://{USER}:{PASSWORD}@{HOST}:{PORT}/{DBNAME}")

# Step 4: Save DataFrame to Postgres (inside schema BHC)
age_segment.to_sql(
    "age_segment",  # table name in postgres
    engine,
    schema="BHC",           # schema name you created
    if_exists="replace",    # options: 'fail', 'replace', 'append'
    index=False             # don’t save pandas index
)


print("Data saved successfully to Postgres!")

# %%
# Uploading test_segment data files to PostgreSQL database

# Step 1: Load CSV
test_segment = pd.read_csv(r"C:\Users\aamreen_quantum-i\OneDrive\Desktop\Symptoms_checker\symptoms_checker\CSV Data\Segments\test_segment.csv")

# Step 2: Connection string (modify with your DB credentials)
USER = "postgres"       # e.g., postgres
PASSWORD = "12345678"   # e.g., 1234
HOST = "localhost"           # or your DB server IP
PORT = "5432"                # default postgres port
DBNAME = "agentdata"       # e.g., hospital_db

# Step 3: Create engine
engine = create_engine(f"postgresql+psycopg2://{USER}:{PASSWORD}@{HOST}:{PORT}/{DBNAME}")

# Step 4: Save DataFrame to Postgres (inside schema BHC)
test_segment.to_sql(
    "test_segment",  # table name in postgres
    engine,
    schema="BHC",           # schema name you created
    if_exists="replace",    # options: 'fail', 'replace', 'append'
    index=False             # don’t save pandas index
)


print("Data saved successfully to Postgres!")

# %%
# Uploading dept_segment data files to PostgreSQL database

# Step 1: Load CSV
dept_segment = pd.read_csv(r"C:\Users\aamreen_quantum-i\OneDrive\Desktop\Symptoms_checker\symptoms_checker\CSV Data\Segments\dept_segment.csv")

# Step 2: Connection string (modify with your DB credentials)
USER = "postgres"       # e.g., postgres
PASSWORD = "12345678"   # e.g., 1234
HOST = "localhost"           # or your DB server IP
PORT = "5432"                # default postgres port
DBNAME = "agentdata"       # e.g., hospital_db

# Step 3: Create engine
engine = create_engine(f"postgresql+psycopg2://{USER}:{PASSWORD}@{HOST}:{PORT}/{DBNAME}")

# Step 4: Save DataFrame to Postgres (inside schema BHC)
dept_segment.to_sql(
    "dept_segment",  # table name in postgres
    engine,
    schema="BHC",           # schema name you created
    if_exists="replace",    # options: 'fail', 'replace', 'append'
    index=False             # don’t save pandas index
)

print("Data saved successfully to Postgres!")

# %%
# Uploading appointment_load data files to PostgreSQL database
import pandas as pd
from sqlalchemy import create_engine

# Step 1: Load CSV
appointment_load = pd.read_csv(r"c:\Users\aamreen_quantum-i\OneDrive\Desktop\Symptoms_checker\symptoms_checker\CSV_Data\doctor_appointment_load.csv")

# Step 2: Connection string (modify with your DB credentials)
USER = "postgres"       # e.g., postgres
PASSWORD = "12345678"   # e.g., 1234
HOST = "localhost"           # or your DB server IP
PORT = "5432"                # default postgres port
DBNAME = "agentdata"       # e.g., hospital_db

# Step 3: Create engine
engine = create_engine(f"postgresql+psycopg2://{USER}:{PASSWORD}@{HOST}:{PORT}/{DBNAME}")

# Step 4: Save DataFrame to Postgres (inside schema BHC)
appointment_load.to_sql(
    "appointment_load",  # table name in postgres
    engine,
    schema="BHC",           # schema name you created
    if_exists="replace",    # options: 'fail', 'replace', 'append'
    index=False             # don’t save pandas index
)

print("Data saved successfully to Postgres!")
# Out:
# Data saved successfully to Postgres!

# %%
#Testing the API endpoint for recommending doctors based on patient info

import requests
url = "http://127.0.0.1:8000/book-appointment/recommend_doctors"
payload = {
    "patient_info": {"id":"P001","name": "asd", "age": 22, "gender": "female"},
    "symptoms": "",
    "test_result": {
        "testname": "ASRS",
        "evaluation_result": {
            "patient_summary": "Your responses indicate possible ADHD symptoms.",
            "detailed_report": {
                "part_a_score": 13,
                "part_b_score": 20,
                "score": 33,
                "interpretation": "Severe ADHD indicators",
                "risk_flags": [],
                "clinical_notes": ["Part A ≥14 suggests ADHD diagnostic consistency"]
            }
        }
    },
    "date": "2025-09-01"
}

response = requests.post(url, json=payload)
print(response.json())
# Out:
# {'Name': {'0': 'Dr. Arjun Joshi', '1': 'Dr. Rahul Bansal', '2': 'Dr. Shweta Ankathi'}, 'Gender': {'0': 'Male', '1': 'Male', '2': 'Female'}, 'Department': {'0': 'Psychiatry', '1': 'Psychiatry', '2': 'Psychiatry'}, 'Available Days': {'0': 'Sat,Mon,Wed', '1': 'Tue,Wed,Mon', '2': 'Thu,Mon,Fri'}, 'Available Slots': {'0': '13:00-14:00,14:00-15:00,15:00-16:00', '1': '11:00-12:00,12:00-13:00,14:00-15:00', '2': '10:00-11:00,12:00-13:00,13:00-14:00'}, 'FinalScore': {'0': 0.7799999999999999, '1': 0.6266666666666667, '2': 0.5466666666666667}}

# %%
import uuid

# %%
import requests
url = "http://127.0.0.1:8000/book-appointment/save_appointment"
payload = {
    "patient_info": {"id":"P001","name": "vever", "age": 27, "gender": "female"},
    "symptoms": "",
    "test_result": {
        "testname": "ASRS",
        "evaluation_result": {
            "patient_summary": "Your responses indicate possible ADHD symptoms.",
            "detailed_report": {
                "part_a_score": 13,
                "part_b_score": 20,
                "score": 33,
                "interpretation": "Severe ADHD indicators",
                "risk_flags": [],
                "clinical_notes": ["Part A ≥14 suggests ADHD diagnostic consistency"]
            }
        }
    },
    "date": "2025-09-09",
    "doctor_details": {
        "Name": "Dr. Arjun Joshi",
        "Department": "Psychiatry",
        "Available Slots": "13:00-14:00,14:00-15:00,15:00-16:00"
    }
}

response = requests.post(url, json=payload)
print(response.json())
# Out:
# {'status': 'success', 'message': 'Appointment saved'}

# %%
import requests
url = "http://127.0.0.1:8000/book-appointment/update_appointment_load"
payload = {
    "patient_info": {"id":"P001","name": "vever", "age": 27, "gender": "female"},
    "symptoms": "",
    "test_result": {
        "testname": "ASRS",
        "evaluation_result": {
            "patient_summary": "Your responses indicate possible ADHD symptoms.",
            "detailed_report": {
                "part_a_score": 13,
                "part_b_score": 20,
                "score": 33,
                "interpretation": "Severe ADHD indicators",
                "risk_flags": [],
                "clinical_notes": ["Part A ≥14 suggests ADHD diagnostic consistency"]
            }
        }
    },
    "date": "2025-08-25",
    "doctor_details": {
        "ID": "D001",
        "Name": "Dr. Arjun Joshi",
        "Department": "Psychiatry",
        "Available Slots": "13:00-14:00,14:00-15:00,15:00-16:00"
    }
}

response = requests.post(url, json=payload)
print(response.json())
# Out:
# {'message': '✅ Updated Doctor D001 on 2025-08-25 (Monday)'}
